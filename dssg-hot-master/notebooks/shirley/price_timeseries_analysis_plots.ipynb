# %%
# %run price_timeseries_analysis_load_and_define_fxns.ipynb

# %% [markdown]
# The following functions are available:
# plot_tp_over_day_by_month(nb_trip_def_id1,nb_trip_def_id2,sb_trip_def_id1,sb_trip_def_id2)
# plot_tp_over_day_by_day_of_week(nb_trip_def_id1,nb_trip_def_id2,sb_trip_def_id1,sb_trip_def_id2)
# plot_tp_over_day_by_month_medstd(nb_trip_def_id1,nb_trip_def_id2,sb_trip_def_id1,sb_trip_def_id2)

# %% [markdown]
# ## Plot travel times

# %% [markdown]
# <i>Remember that there are 2 equivalent trip def ids for each price
# (separated by 45, switching over halfway through the year)</i>
#
# --> In the fxns used below and listed above, denote both of those ids

# %%
# - Plot full corridor toll prices over the day by month (orange=northbound, green=southbound)
plot_tp_over_day_by_month('2689','2734','2715','2760')

# %%
# - Plot SB full corridor travel times over the day by day of the week
plot_tp_over_day_by_day_of_week('2689','2734','2715','2760')

# %%
# - Plot full corridor toll prices over the day by month
# (orange=northbound, green=southbound) w/ medians and stdevs
plot_tp_over_day_by_month_medstd('2689','2734','2715','2760')
