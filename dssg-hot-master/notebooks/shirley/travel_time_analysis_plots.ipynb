# %%
# %run travel_time_analysis_load_and_define_fxns.ipynb

# %% [markdown]
# The following functions are available:
# plot_tt_over_day_by_month(tt_or_tts, entry_plaza, exit_plaza)
# plot_tt_over_day_by_day_of_week(tt_or_tts, entry_plaza, exit_plaza)
# plot_tt_over_day_by_day_of_week_medstd(tt_or_tts, entry_plaza, exit_plaza)

# %% [markdown]
# ## Plot travel times

# %%
# - Plot SB full corridor travel times over the day by month
plot_tt_over_day_by_month('tt',13,23)

# %%
# - Plot NB full corridor travel times over the day by month
plot_tt_over_day_by_month('tt',3,12)

# %%
# - Plot SB full corridor travel times over the day by day of the week
plot_tt_over_day_by_day_of_week('tt',13,23)

# %%
# - Plot NB full corridor travel times over the day by day of the week
plot_tt_over_day_by_day_of_week('tt',3,12)

# %%
# - Plot SB full corridor travel times over the day by day of the week w/ medians and stdevs
plot_tt_over_day_by_day_of_week_medstd('tt',13,23)

# %%
# - Plot NB full corridor travel times over the day by day of the week w/ medians and stdevs
plot_tt_over_day_by_day_of_week_medstd('tt',3,12)

# %% [markdown]
# ## Plot travel time savings

# %%
# - Plot SB full corridor travel time savings over the day by month
plot_tt_over_day_by_month('tts', 13, 23)

# %%
# - Plot NB full corridor travel time savings over the day by month
plot_tt_over_day_by_month('tts', 3, 12)

# %%
# - Plot SB full corridor travel time savings over the day by day of the week
plot_tt_over_day_by_day_of_week('tts',13,23)

# %%
# - Plot NB full corridor travel time savings over the day by day of the week
plot_tt_over_day_by_day_of_week('tts',3,12)

# %%
# - Plot SB full corridor travel time savings over the day by day of the week w/ medians and stdevs
plot_tt_over_day_by_day_of_week_medstd('tts',13,23)

# %%
# - Plot NB full corridor travel time savings over the day by day of the week w/ medians and stdevs
plot_tt_over_day_by_day_of_week_medstd('tts',3,12)
