# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/opt/dssg-hot/data/toll_prices/concatenated_405_prices_2018.csv')

# %%
df.head()
# Out:
#                   Time  2689  2690  2691  2692  2693  2694  2695  2696  2697  \
# 0  2018-01-01 05:01:59   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  2018-01-01 05:02:00   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  2018-01-01 05:02:01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  2018-01-01 05:02:02   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2018-01-01 05:04:50   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    ...  2769  2770  2771  2772  2773  2774  2731  2732  2733  2746
# 0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 84 columns]

# %%
df['newtime'] = pd.to_datetime(df['Time'])
df['weekday_num'] = df['newtime'].apply(lambda t: t.weekday())
df['month_num'] = df['newtime'].apply(lambda t: t.month)
df['hour_num'] = df['newtime'].apply(lambda t: t.hour)
df['time_of_day'] = df['newtime'].apply(lambda t: t.time())

# %%
weekday_num_grouped = df.groupby('weekday_num')
weekday_num_stds = weekday_num_grouped.aggregate(np.std)
weekday_num_meds = weekday_num_grouped.aggregate(np.median)

# %%
weekdayxtimeofday_grouped = df.groupby(['weekday_num','time_of_day'])
weekdayxtimeofday_stds = weekdayxtimeofday_grouped.aggregate(np.std)
weekdayxtimeofday_meds = weekdayxtimeofday_grouped.aggregate(np.median)

# %%
weekdayxtimeofday_meds
# Out:
#                          2689  2690  2691  2692  2693  2694  2695  2696  2697  \
# weekday_num time_of_day
# 0           05:00:00      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#             05:00:01      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#             05:00:02      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#             05:00:05      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#             05:00:06      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#             05:00:07      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#             05:00:08      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#             05:00:10      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#             05:00:11      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#             05:00:12      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#             05:00:15      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
plt.plot(df['2689'])

# %%
# - Plot toll prices over the day by day of the week
# fill_between
fig, axs = plt.subplots(5, figsize=(10,20), sharex=True, sharey=True)
#bigax = fig.add_subplot(111)
#bigax.set_xlabel('Time of day (hour)')
#bigax.set_ylabel('Travel time (minutes)')
#fig.suptitle('Each day of the week prices')
for day in range(0,5):
    #axs[day].plot(weekdayxtimeofday_meds['2689'][day]+weekdayxtimeofday_stds['2689'][day],'r--')
    axs[day].plot(weekdayxtimeofday_meds['2689'][day],'r.') # northbound full corridor
    #axs[day].plot(weekdayxtimeofday_meds['2689'][day]-weekdayxtimeofday_stds['2689'][day],'r--')
    #axs[day].plot(weekdayxtimeofday_meds['2771'][day]+weekdayxtimeofday_stds['2771'][day],'g--')
    axs[day].plot(weekdayxtimeofday_meds['2715'][day],'b.') # southbound full corridor
    #axs[day].plot(weekdayxtimeofday_meds['2771'][day]-weekdayxtimeofday_stds['2771'][day],'g--')
